# %%
import gc
gc.collect()
# Out:
# 656

# %%
import pandas as pd
import datetime
import numpy as np
import json

# %%
data_fr = pd.read_csv('../data/df_fr.csv', sep=',')
corres_ICD10 = pd.read_csv('../data/corres_ICD10.csv', sep=';', header = None)

# %%
data_fr.columns = ['categorie','unit','sex','age','icd10','geo','2015','2014','2013','2012','2011','2010','2009','2008','2007','2006','2005','2004','2003','2002','2001','2000','1999','1998','1997','1996','1995','1994']
data_fr
# Out:
#        categorie unit sex     age         icd10   geo      2015      2014  \
# 0            144   RT   F   TOTAL       A-R_V-Y    FR   864.04    810.56
# 1            145   RT   F   TOTAL       A-R_V-Y  FR10   602.05    569.34
# 2            146   RT   F   TOTAL       A-R_V-Y  FR21   971.97    895.16
# 3            147   RT   F   TOTAL       A-R_V-Y  FR22   893.97    836.16
# 4            148   RT   F   TOTAL       A-R_V-Y  FR23   888.27    840.43
# 5            149   RT   F   TOTAL       A-R_V-Y  FR24   977.34    894.21
# 6            150   RT   F   TOTAL       A-R_V-Y  FR25  1007.38    961.31
# 7            151   RT   F   TOTAL       A-R_V-Y  FR26  1104.36   1008.95
# 8            152   RT   F   TOTAL       A-R_V-Y  FR30   883.36    832.85
# 9            153   RT   F   TOTAL       A-R_V-Y  FR41   971.72    893.21
# 10           154   RT   F   TOTAL       A-R_V-Y  FR42   850.48    768.07
# 11           155   RT   F   TOTAL       A-R_V-Y  FR43   898.19    849.11
# 12           156   RT   F   TOTAL       A-R_V-Y  FR51   872.59    798.05
# 13           157   RT   F   TOTAL       A-R_V-Y  FR52  1008.08    945.58
# 14           158   RT   F   TOTAL       A-R_V-Y  FR53  1042.55    967.19
# 15           159   RT   F   TOTAL       A-R_V-Y  FR61   975.37    936.03
# 16           160   RT   F   TOTAL       A-R_V-Y  FR62   942.69     889.8
# 17           161   RT   F   TOTAL       A-R_V-Y  FR63   1258.3   1133.92
# 18           162   RT   F   TOTAL       A-R_V-Y  FR71    780.7    729.95
# 19           163   RT   F   TOTAL       A-R_V-Y  FR72  1126.78   1018.02
# 20           164   RT   F   TOTAL       A-R_V-Y  FR81   955.71    907.02
# 21           165   RT   F   TOTAL       A-R_V-Y  FR82   966.87    908.88
# 22           166   RT   F   TOTAL       A-R_V-Y  FR83   889.36    901.11
# 23           167   RT   F   TOTAL       A-R_V-Y  FR91        :         :
# 24           168   RT   F   TOTAL       A-R_V-Y  FR92        :         :
# 25           169   RT   F   TOTAL       A-R_V-Y  FR93        :         :
# 26           170   RT   F   TOTAL       A-R_V-Y  FR94        :         :
# 27           455   RT   F   TOTAL   A15-A19_B90    FR     0.63      0.64
# 28           456   RT   F   TOTAL   A15-A19_B90  FR10     0.67      0.56
# 29           457   RT   F   TOTAL   A15-A19_B90  FR21     0.87      0.73
# ...          ...  ...  ..     ...           ...   ...       ...       ...
# 25480     375854   RT   T  Y_LT65  X85-Y09_Y871  FR92        :         :
# 25481     375855   RT   T  Y_LT65  X85-Y09_Y871  FR93        :         :
# 25502     2.4      3.3      5.0      5.5      4.0
# 25503     3.6      2.9      2.4      3.6      3.8
# 25504     3.9      3.0      4.4      5.2      5.0
# 25505     4.2      3.8      5.6     14.6      9.9
# 25506       :        :        :        :        :
# 25507       :        :        :        :        :
# 25508       :        :        :        :        :
# 25509       :        :        :        :        :
#
# [25510 rows x 28 columns]

# %%
categorie_0 = ['A-R_V-Y']
categorie_1 = ['A-U','V01-Y89']
categorie_2 = ['A_B','C00-D48','E','F','TOXICO','G_H','I','J','K','L','M,','N','O','P','Q','R']

# %%
corres_list = corres_ICD10[0].values.tolist()
corres_list
# Out:
# ['A-R_V-Y',
#  'A-U',
#  'A_B',
#  'A15-A19_B90',
#  'B15-B19_B942',
#  'B20-B24',
#  'A_B_OTH',
#  'C00-D48',
#  'C',
#  'C00-C14',
#  'C15',
#  'C16',
#  'C18-C21',
#  'C22',
#  'C25',
#  'C32',
#  'C33_C34',
#  'C43',
#  'C50',
#  'C53',
#  'C54_C55',
#  'C56',
#  'C61',
#  'C64',
#  'C67',
#  'C70-C72',
#  'C73',
#  'C81-C86',
#  'C88_C90_C96',
#  'C91-C95',
#  'C_OTH',
#  'D00-D48',
#  'D50-D89',
#  'E',
#  'E10-E14',
#  'E_OTH',
#  'F',
#  'F01_F03',
#  'F10',
#  'TOXICO',
#  'F_OTH',
#  'G_H',
#  'G20',
#  'G30',
#  'G_H_OTH',
#  'I',
#  'I20-I25',
#  'I21_I22',
#  'I20_I23-I25',
#  'I30-I51',
#  'I60-I69',
#  'I_OTH',
#  'J',
#  'J09-J11',
#  'J12-J18',
#  'J40-J47',
#  'J45_J46',
#  'J40-J44_J47',
#  'J_OTH',
#  'K',
#  'K25-K28',
#  'K70_K73_K74',
#  'K_OTH',
#  'L',
#  'M',
#  'RHEUM_ARTHRO',
#  'M_OTH',
#  'N',
#  'N00-N29',
#  'N_OTH',
#  'O',
#  'P',
#  'Q',
#  'R',
#  'R95',
#  'R96-R99',
#  'R_OTH',
#  'V01-Y89',
#  'ACC',
#  'V_Y85',
#  'ACC_OTH',
#  'W00-W19',
#  'W65-W74',
#  'X60-X84_Y870',
#  'X40-X49',
#  'X85-Y09_Y871',
#  'Y10-Y34_Y872',
#  'V01-Y89_OTH']

# %%
categorie_3 = corres_list
for elt in categorie_0:
    try:
        categorie_3.remove(elt);
    except:
        pass
for elt in categorie_1:
    try:
        categorie_3.remove(elt);
    except:
        pass
for elt in categorie_2:
    try:
        categorie_3.remove(elt);
    except:
        pass
categorie_3
# Out:
# ['A15-A19_B90',
#  'B15-B19_B942',
#  'B20-B24',
#  'A_B_OTH',
#  'C',
#  'C00-C14',
#  'C15',
#  'C16',
#  'C18-C21',
#  'C22',
#  'C25',
#  'C32',
#  'C33_C34',
#  'C43',
#  'C50',
#  'C53',
#  'C54_C55',
#  'C56',
#  'C61',
#  'C64',
#  'C67',
#  'C70-C72',
#  'C73',
#  'C81-C86',
#  'C88_C90_C96',
#  'C91-C95',
#  'C_OTH',
#  'D00-D48',
#  'D50-D89',
#  'E10-E14',
#  'E_OTH',
#  'F01_F03',
#  'F10',
#  'F_OTH',
#  'G20',
#  'G30',
#  'G_H_OTH',
#  'I20-I25',
#  'I21_I22',
#  'I20_I23-I25',
#  'I30-I51',
#  'I60-I69',
#  'I_OTH',
#  'J09-J11',
#  'J12-J18',
#  'J40-J47',
#  'J45_J46',
#  'J40-J44_J47',
#  'J_OTH',
#  'K25-K28',
#  'K70_K73_K74',
#  'K_OTH',
#  'M',
#  'RHEUM_ARTHRO',
#  'M_OTH',
#  'N00-N29',
#  'N_OTH',
#  'R95',
#  'R96-R99',
#  'R_OTH',
#  'ACC',
#  'V_Y85',
#  'ACC_OTH',
#  'W00-W19',
#  'W65-W74',
#  'X60-X84_Y870',
#  'X40-X49',
#  'X85-Y09_Y871',
#  'Y10-Y34_Y872',
#  'V01-Y89_OTH']

# %%
def categorize(ele):
    if ele in categorie_3:
        return 3
    else:
        if ele in categorie_1:
            return 1
        else:
            if ele in categorie_2:
                return 2
            else:
                return 0
data_fr['categorie'] = data_fr['icd10'].apply(categorize)

# %%
data_fr.to_csv('../data/data_fr_new.csv')

# %%
data_fr
# Out:
#        categorie unit sex     age         icd10   geo      2015      2014  \
# 0              0   RT   F   TOTAL       A-R_V-Y    FR   864.04    810.56
# 1              0   RT   F   TOTAL       A-R_V-Y  FR10   602.05    569.34
# 2              0   RT   F   TOTAL       A-R_V-Y  FR21   971.97    895.16
# 3              0   RT   F   TOTAL       A-R_V-Y  FR22   893.97    836.16
# 4              0   RT   F   TOTAL       A-R_V-Y  FR23   888.27    840.43
# 5              0   RT   F   TOTAL       A-R_V-Y  FR24   977.34    894.21
# 6              0   RT   F   TOTAL       A-R_V-Y  FR25  1007.38    961.31
# 7              0   RT   F   TOTAL       A-R_V-Y  FR26  1104.36   1008.95
# 8              0   RT   F   TOTAL       A-R_V-Y  FR30   883.36    832.85
# 9              0   RT   F   TOTAL       A-R_V-Y  FR41   971.72    893.21
# 10             0   RT   F   TOTAL       A-R_V-Y  FR42   850.48    768.07
# 11             0   RT   F   TOTAL       A-R_V-Y  FR43   898.19    849.11
# 12             0   RT   F   TOTAL       A-R_V-Y  FR51   872.59    798.05
# 13             0   RT   F   TOTAL       A-R_V-Y  FR52  1008.08    945.58
# 14             0   RT   F   TOTAL       A-R_V-Y  FR53  1042.55    967.19
# 15             0   RT   F   TOTAL       A-R_V-Y  FR61   975.37    936.03
# 16             0   RT   F   TOTAL       A-R_V-Y  FR62   942.69     889.8
# 17             0   RT   F   TOTAL       A-R_V-Y  FR63   1258.3   1133.92
# 18             0   RT   F   TOTAL       A-R_V-Y  FR71    780.7    729.95
# 19             0   RT   F   TOTAL       A-R_V-Y  FR72  1126.78   1018.02
# 20             0   RT   F   TOTAL       A-R_V-Y  FR81   955.71    907.02
# 21             0   RT   F   TOTAL       A-R_V-Y  FR82   966.87    908.88
# 22             0   RT   F   TOTAL       A-R_V-Y  FR83   889.36    901.11
# 23             0   RT   F   TOTAL       A-R_V-Y  FR91        :         :
# 24             0   RT   F   TOTAL       A-R_V-Y  FR92        :         :
# 25             0   RT   F   TOTAL       A-R_V-Y  FR93        :         :
# 26             0   RT   F   TOTAL       A-R_V-Y  FR94        :         :
# 27             3   RT   F   TOTAL   A15-A19_B90    FR     0.63      0.64
# 28             3   RT   F   TOTAL   A15-A19_B90  FR10     0.67      0.56
# 29             3   RT   F   TOTAL   A15-A19_B90  FR21     0.87      0.73
# ...          ...  ...  ..     ...           ...   ...       ...       ...
# 25480          3   RT   T  Y_LT65  X85-Y09_Y871  FR92        :         :
# 25481          3   RT   T  Y_LT65  X85-Y09_Y871  FR93        :         :
# 25482          3   RT   T  Y_LT65  X85-Y09_Y871  FR94        :         :
# 25483          3   RT   T  Y_LT65  Y10-Y34_Y872    FR     1.11      0.98
# 25484          3   RT   T  Y_LT65  Y10-Y34_Y872  FR10     0.94      0.62
# 25485          3   RT   T  Y_LT65  Y10-Y34_Y872  FR21     0.65      0.92
# 25486          3   RT   T  Y_LT65  Y10-Y34_Y872  FR22     1.87      0.99
# 25487          3   RT   T  Y_LT65  Y10-Y34_Y872  FR23     1.31      1.18
# 25488          3   RT   T  Y_LT65  Y10-Y34_Y872  FR24     0.88      1.32
# 25489          3   RT   T  Y_LT65  Y10-Y34_Y872  FR25     1.03      1.54
# 25490          3   RT   T  Y_LT65  Y10-Y34_Y872  FR26     1.34      0.62
# 25491          3   RT   T  Y_LT65  Y10-Y34_Y872  FR30     1.17      0.61
# 25492          3   RT   T  Y_LT65  Y10-Y34_Y872  FR41     0.69      0.79
# 25493          3   RT   T  Y_LT65  Y10-Y34_Y872  FR42     1.16      0.51
# 25494          3   RT   T  Y_LT65  Y10-Y34_Y872  FR43     1.58      1.26
# 25495          3   RT   T  Y_LT65  Y10-Y34_Y872  FR51     0.63      0.76
# 25496          3   RT   T  Y_LT65  Y10-Y34_Y872  FR52     1.45       1.3
# 25497          3   RT   T  Y_LT65  Y10-Y34_Y872  FR53      1.3      0.86
# 25498          3   RT   T  Y_LT65  Y10-Y34_Y872  FR61     1.05      0.75
# 25499          3   RT   T  Y_LT65  Y10-Y34_Y872  FR62     1.13      1.18
# 25500          3   RT   T  Y_LT65  Y10-Y34_Y872  FR63     0.36      0.18
# 25501          3   RT   T  Y_LT65  Y10-Y34_Y872  FR71     0.86      1.12
# 25502          3   RT   T  Y_LT65  Y10-Y34_Y872  FR72     1.14       1.6
# 25503          3   RT   T  Y_LT65  Y10-Y34_Y872  FR81     0.73      1.52
# 25504          3   RT   T  Y_LT65  Y10-Y34_Y872  FR82     1.32      1.09
# 25505          3   RT   T  Y_LT65  Y10-Y34_Y872  FR83     1.17      1.56
# 25506          3   RT   T  Y_LT65  Y10-Y34_Y872  FR91        :         :
# 25507          3   RT   T  Y_LT65  Y10-Y34_Y872  FR92        :         :
# 25508          3   RT   T  Y_LT65  Y10-Y34_Y872  FR93        :         :
# 25509          3   RT   T  Y_LT65  Y10-Y34_Y872  FR94        :         :
#
#            2013      2012  ...     2003     2002     2001     2000     1999  \
# 25490     2.1      2.8      1.9      3.7      2.6
# 25491     3.1      3.6      2.9      3.4      2.8
# 25492     3.0      2.1      3.2      3.4      3.3
# 25493     2.0      1.1      1.8      1.4      2.9
# 25494     3.3      3.7      3.5      3.5      3.8
# 25495     3.0      3.4      2.6      3.1      3.7
# 25496     4.1      3.4      4.6      3.9      4.8
# 25497     2.8      3.0      4.3      4.3      3.1
# 25498     2.9      3.5      3.7      3.3      3.2
# 25499     2.9      2.4      1.9      2.2      3.2
# 25500     3.6      1.6      3.6      4.5      3.7
# 25501     3.2      3.5      2.9      3.9      4.5
# 25502     2.4      3.3      5.0      5.5      4.0
# 25503     3.6      2.9      2.4      3.6      3.8
# 25504     3.9      3.0      4.4      5.2      5.0
# 25505     4.2      3.8      5.6     14.6      9.9
# 25506       :        :        :        :        :
# 25507       :        :        :        :        :
# 25508       :        :        :        :        :
# 25509       :        :        :        :        :
#
# [25510 rows x 28 columns]

# %%
icd10_dict = corres_ICD10.set_index(0).loc[:,1].to_dict()

# %%
icd10_dict
# Out:
# {'A-R_V-Y': 'Toutes causes de mortalit� (A00-Y89) sauf S00-T98',
#  'A-U': 'Causes interne de morbidit� et mortalit� ',
#  'A_B': 'Certaines maladies infectieuses et parasitaires (A00-B99)',
#  'A15-A19_B90': 'Tuberculose',
#  'B15-B19_B942': "H�patite virale et s�quelles d'h�patite virale",
#  'B20-B24': "Maladies dues au virus de l'immunod�ficience humaine [VIH]",
#  'A_B_OTH': 'Autres certaines maladies infectieuses et parasitaires (partie restante de A00-B99)',
#  'C00-D48': 'Tumeurs',
#  'C': 'Tumeurs malignes (C00-C97)',
#  'C00-C14': 'Tumeur maligne de la l�vre, de la cavit� buccale et du pharynx',
#  'C15': "Tumeur maligne de l'oesophage",
#  'C16': "Tumeur maligne de l'estomac",
#  'C18-C21': "Tumeur maligne du c�lon, de la jonction recto-sigmo�dienne, du rectum, de l'anus et du canal anal",
#  'C22': 'Tumeur maligne du foie et des voies biliaires intrah�patiques',
#  'C25': 'Tumeur maligne du pancr�as',
#  'C32': 'Tumeur maligne du larynx',
#  'C33_C34': 'Tumeur maligne de la trach�e et des bronches et du poumon',
#  'C43': 'M�lanome malin de la peau',
#  'C50': 'Tumeur maligne du sein',
#  'C53': "Tumeur maligne du col de l'ut�rus",
#  'C54_C55': "Tumeur maligne d'autres parties de l'ut�rus",
#  'C56': "Tumeur maligne de l'ovaire",
#  'C61': 'Tumeur maligne de la prostate',
#  'C64': "Tumeur maligne du rein, � l'exception du bassinet",
#  'C67': 'Tumeur maligne de la vessie',
#  'C70-C72': 'Tumeur maligne du cerveau et du syst�me nerveux central',
#  'C73': 'Tumeur maligne de la thyro�de',
#  'C81-C86': 'Maladie de Hodgkin et lymphomes',
#  'C88_C90_C96': 'Autre tumeurs malignes des tissus lympho�de, h�matopo��tique et apparent�s',
#  'C91-C95': 'Leuc�mie',
#  'C_OTH': 'Autres tumeurs malignes (partie restante de C00-C97)',
#  'D00-D48': 'Tumeurs non malignes (b�nignes et incertaines)',
#  'D50-D89': 'Maladies du sang et des organes h�matopo��tiques et certains troubles du syst�me immunitaire',
#  'E': 'Maladies endocriniennes, nutritionnelles et m�taboliques (E00-E90)',
#  'E10-E14': 'Diab�te sucr�',
#  'E_OTH': 'Autres maladies endocriniennes, nutritionnelles et m�taboliques (partie restante de E00-E90)',
#  'F': 'Troubles mentaux et du comportement (F00-F99)',
#  'F01_F03': 'D�mence',
#  'F10': "Troubles mentaux et du comportement li�s � l'utilisation d'alcool",
#  'TOXICO': 'Pharmacod�pendance, toxicomanie (F11-F16, F18-F19)',
#  'F_OTH': 'Autres troubles mentaux et du comportement (partie restante de F00-F99)',
#  'G_H': 'Maladies du syst�me nerveux et des organes des sens (G00-H95)',
#  'G20': 'Maladie de Parkinson',
#  'G30': "Maladie d'Alzheimer",
#  'G_H_OTH': 'Autres maladies du syst�me nerveux et des organes des sens (partie restante de G00-H95)',
#  'I': "Maladies de l'appareil circulatoire (I00-I99)",
#  'I20-I25': 'Cardiopathies isch�miques',
#  'I21_I22': 'Infarctus aigu du myocarde et infarctus du myocarde � r�p�tition',
#  'I20_I23-I25': 'Autres cardiopathies isch�miques',
#  'I30-I51': 'Autres maladies cardiovasculaires',
#  'I60-I69': 'Maladies c�r�brovasculaires',
#  'I_OTH': "Autres maladies de l'appareil circulatoire (partie restante de I00-I99)",
#  'J': "Maladies de l'appareil respiratoire (J00-J99)",
#  'J09-J11': 'Grippe (grippe porcine incluse)',
#  'J12-J18': 'Pneumonie',
#  'J40-J47': 'Maladies chroniques des voies respiratoires inf�rieures',
#  'J45_J46': 'Asthme et �tat de mal asthmatique',
#  'J40-J44_J47': 'Autres maladies des voies respiratoires inf�rieures',
#  'J_OTH': 'Autres maladie de l�appareil respiratoire (partie restante de J00-J99)',
#  'K': "Maladies de l'appareil digestif (K00-K93)",
#  'K25-K28': 'Ulc�re digestif et ulc�re gastro-duod�nal',
#  'K70_K73_K74': 'Maladie chronique du foie',
#  'K_OTH': "Autres maladies de l'appareil digestif (partie restante de K00-K93)",
#  'L': 'Maladies de la peau et du tissu cellulaire sous-cutan� (L00-L99)',
#  'M': 'Maladies du syst�me ost�o-articulaire, des muscles et du tissu conjonctif (M00-M99)',
#  'RHEUM_ARTHRO': 'Arthrite rhumato�de et ost�o-arthrite (M05-M06, M15-M19)',
#  'M_OTH': 'Autres maladies du syst�me ost�o-articulaire, des muscles et du tissu conjonctif (partie restante de M00-M99)',
#  'N': "Maladies de l'appareil g�nito-urinaire (N00-N99)",
#  'N00-N29': "Maladies du rein et de l'uret�re",
#  'N_OTH': "Autres maladies de l'appareil g�nito-urinaire (partie restante de N00-N99)",
#  'O': 'Complications de grossesse, accouchement et puerp�ralit� (O00-O99)',
#  'P': "Certaines affections dont l'origine se situe dans la p�riode p�rinatale (P00-P96)",
#  'Q': 'Malformations cong�nitales et anomalies chromosomiques (Q00-Q99)',
#  'R': "Sympt�mes, signes et r�sultats anormaux d'examens cliniques et de laboratoire, non class�s ailleurs (R00-R99)",
#  'R95': 'Syndrome de la mort subite du nourrisson',
#  'R96-R99': 'Causes inconnues ou non pr�cis�es de mortalit�',
#  'R_OTH': "Autres sympt�mes, signes et r�sultats anormaux d'examens cliniques et de laboratoire (partie restante de R00-R99)",
#  'V01-Y89': 'Causes externes de morbidit� et mortalit� (V01-Y89)',
#  'ACC': 'Accidents (V01-X59, Y85, Y86)',
#  'V_Y85': 'Accidents de transport (V01-V99, Y85)',
#  'ACC_OTH': 'Autres accidents (W20-W64, W75-X39, X50-X59, Y86)',
#  'W00-W19': 'Chutes',
#  'W65-W74': 'Noyade et submersion accidentelles',
#  'X60-X84_Y870': 'Suicides',
#  'X40-X49': 'Intoxication accidentelle par des substances nocives et exposition � ces substances',
#  'X85-Y09_Y871': 'Homicides',
#  'Y10-Y34_Y872': "Ev�nements dont l'intention n'est pas d�termin�e",
#  'V01-Y89_OTH': 'Autres causes externes de morbidit� et mortalit� (partie restante de V01-Y89)'}

# %% [markdown]
# ## Partie SEB

# %%
for col in data_fr.columns[6:]:
    data_fr[col] = data_fr[col].str.strip().replace({":":"NaN", ": z":"NaN"}).astype('float64')

# %%
data_fr.head()
# Out:
#    categorie unit sex    age    icd10   geo    2015    2014    2013    2012  \
# 0          0   RT   F  TOTAL  A-R_V-Y    FR  864.04  810.56  816.66  824.57
# 1          0   RT   F  TOTAL  A-R_V-Y  FR10  602.05  569.34  585.50  593.06
# 2          0   RT   F  TOTAL  A-R_V-Y  FR21  971.97  895.16  938.19  929.00
# 3          0   RT   F  TOTAL  A-R_V-Y  FR22  893.97  836.16  867.00  871.19
# 4          0   RT   F  TOTAL  A-R_V-Y  FR23  888.27  840.43  850.80  861.78
#
#    ...   2003   2002   2001   2000   1999   1998   1997   1996   1995   1994
# 0  ...  868.2  839.1  835.3    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1  ...  684.3  640.7  649.4  649.2  660.7  670.5  671.1  681.2  686.3  669.9
# 2  ...  898.5  866.6  870.9  877.6  900.1  858.5  861.1  874.0  881.0  842.5
# 3  ...  880.7  844.1  830.9  829.0  839.5  828.4  838.8  844.8  834.7  794.2
# 4  ...  867.2  827.0  833.0  820.2  814.5  830.9  811.7  844.8  833.0  777.1
#
# [5 rows x 28 columns]

# %%
colIndex = pd.MultiIndex.from_product([data_fr.geo.unique(),
                                       data_fr.sex.unique(),
                                       data_fr.age.unique(),
                                       data_fr.icd10.unique()],
                                      names=['Region','Sexe','Age','Maladie'])

# %%
# df = data_fr.set_index(['geo', 'sex', 'age', 'icd10']).drop(columns=['categorie', 'unit'])
df = data_fr.groupby(['geo', 'sex']).sum().drop(columns=["categorie"])

# %%
import collections

# %%
def nested_dict():
    return collections.defaultdict(nested_dict)
result = nested_dict()

# %%
for row in df.itertuples():
    result[row.Index[0]][row.Index[1]]['2015'] = row._1
#     print(row)

# %%
out = json.dumps(result)

# %%
out = data_fr.groupby(['geo', 'sex', 'age', 'icd10']).sum()["2015"].to_json(orient='table')

# %%
with open('data.json', 'w') as f:
    f.write(out)
