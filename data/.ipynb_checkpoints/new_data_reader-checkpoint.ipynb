# %%
import pandas as pd
import datetime
import numpy as np

# %%
data_fr = pd.read_csv('../data/df_fr.csv', sep=',')
corres_ICD10 = pd.read_csv('../data/corres_ICD10.csv', sep=';', header = None)
corres_ICD10
# Out:
#                0                                                  1
# 0        A-R_V-Y  Toutes causes de mortalit� (A00-Y89) sauf S00-T98
# 1            A-U          Causes interne de morbidit� et mortalit�
# 2            A_B  Certaines maladies infectieuses et parasitaire...
# 3    A15-A19_B90                                        Tuberculose
# 4   B15-B19_B942     H�patite virale et s�quelles d'h�patite virale
# 5        B20-B24  Maladies dues au virus de l'immunod�ficience h...
# 6        A_B_OTH  Autres certaines maladies infectieuses et para...
# 7        C00-D48                                            Tumeurs
# 8              C                         Tumeurs malignes (C00-C97)
# 9        C00-C14  Tumeur maligne de la l�vre, de la cavit� bucca...
# 10           C15                      Tumeur maligne de l'oesophage
# 11           C16                        Tumeur maligne de l'estomac
# 12       C18-C21  Tumeur maligne du c�lon, de la jonction recto-...
# 13           C22  Tumeur maligne du foie et des voies biliaires ...
# 14           C25                         Tumeur maligne du pancr�as
# 15           C32                           Tumeur maligne du larynx
# 16       C33_C34  Tumeur maligne de la trach�e et des bronches e...
# 17           C43                          M�lanome malin de la peau
# 18           C50                             Tumeur maligne du sein
# 19           C53                  Tumeur maligne du col de l'ut�rus
# 20       C54_C55        Tumeur maligne d'autres parties de l'ut�rus
# 21           C56                         Tumeur maligne de l'ovaire
# 22           C61                      Tumeur maligne de la prostate
# 23           C64  Tumeur maligne du rein, � l'exception du bassinet
# 24           C67                        Tumeur maligne de la vessie
# 25       C70-C72  Tumeur maligne du cerveau et du syst�me nerveu...
# 26           C73                      Tumeur maligne de la thyro�de
# 27       C81-C86                    Maladie de Hodgkin et lymphomes
# 28   C88_C90_C96  Autre tumeurs malignes des tissus lympho�de, h...
# 29       C91-C95                                           Leuc�mie
# ..           ...                                                ...
# 58         J_OTH  Autres maladie de l�appareil respiratoire (par...
# 59             K          Maladies de l'appareil digestif (K00-K93)
# 60       K25-K28          Ulc�re digestif et ulc�re gastro-duod�nal
# 61   K70_K73_K74                          Maladie chronique du foie
# 62         K_OTH  Autres maladies de l'appareil digestif (partie...
# 63             L  Maladies de la peau et du tissu cellulaire sou...
# 64             M  Maladies du syst�me ost�o-articulaire, des mus...
# 65  RHEUM_ARTHRO  Arthrite rhumato�de et ost�o-arthrite (M05-M06...
# 66         M_OTH  Autres maladies du syst�me ost�o-articulaire, ...
# 67             N   Maladies de l'appareil g�nito-urinaire (N00-N99)
# 68       N00-N29                   Maladies du rein et de l'uret�re
# 69         N_OTH  Autres maladies de l'appareil g�nito-urinaire ...
# 70             O  Complications de grossesse, accouchement et pu...
# 71             P  Certaines affections dont l'origine se situe d...
# 72             Q  Malformations cong�nitales et anomalies chromo...
# 73             R  Sympt�mes, signes et r�sultats anormaux d'exam...
# 74           R95           Syndrome de la mort subite du nourrisson
# 75       R96-R99     Causes inconnues ou non pr�cis�es de mortalit�
# 76         R_OTH  Autres sympt�mes, signes et r�sultats anormaux...
# 77       V01-Y89  Causes externes de morbidit� et mortalit� (V01...
# 78           ACC                      Accidents (V01-X59, Y85, Y86)
# 79         V_Y85              Accidents de transport (V01-V99, Y85)
# 80       ACC_OTH  Autres accidents (W20-W64, W75-X39, X50-X59, Y86)
# 81       W00-W19                                             Chutes
# 82       W65-W74                 Noyade et submersion accidentelles
# 83  X60-X84_Y870                                           Suicides
# 84       X40-X49  Intoxication accidentelle par des substances n...
# 85  X85-Y09_Y871                                          Homicides
# 86  Y10-Y34_Y872   Ev�nements dont l'intention n'est pas d�termin�e
# 87   V01-Y89_OTH  Autres causes externes de morbidit� et mortali...
#
# [88 rows x 2 columns]

# %%
data_fr.columns = ['categorie','unit','sex,','age','icd10','geo','2015','2014','2013','2012','2011','2010','2009','2008','2007','2006','2005','2004','2003','2002','2001','2000','1999','1998','1997','1996','1995','1994']

# %%
categorie_0 = ['A-R_V-Y']
categorie_1 = ['A-U','V01-Y89']
categorie_2 = ['A_B','C00-D48','E','F','TOXICO','G_H','I','J','K','L','M,','N','O','P','Q','R']

# %%
corres_list = corres_ICD10[0].values.tolist()

# %%
categorie_3 = corres_list
for elt in categorie_0:
    try:
        categorie_3.remove(elt);
    except:
        pass
for elt in categorie_1:
    try:
        categorie_3.remove(elt);
    except:
        pass
for elt in categorie_2:
    try:
        categorie_3.remove(elt);
    except:
        pass
